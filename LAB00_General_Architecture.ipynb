# %% [markdown]
# ## Data Lake Workshop

# %% [markdown]
# Welcome to the Data Lake Workshop!
#
# In this workshop, we will create a data lake step by step, using various AWS tools.
#
# The final architecture should be something like this:

# %% [markdown]
# ![LAB00_General_Architecture.png](attachment:LAB00_General_Architecture.png)
