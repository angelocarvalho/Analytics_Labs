# %% [markdown]
# ## Now it's time to go to Quicksight to create some dashboards. We are going to display a chart with the best rated movies:

# %% [markdown]
# ![LAB09_Quicksight.png](attachment:LAB09_Quicksight.png)

# %% [markdown]
# ## 1) Select quicksight in the AWS Console and hit the "Sign Up" button.

# %% [markdown]
# ![quicksight_01.png](attachment:quicksight_01.png)

# %% [markdown]
# ## 2) Fill the field as the image bellow:

# %% [markdown]
# ![quicksight_02.png](attachment:quicksight_02.png)

# %% [markdown]
# ## 3) Don't forget to give access to you data lake bucket:

# %% [markdown]
# ![quicksight_03.png](attachment:quicksight_03.png)

# %% [markdown]
# ## 4) Now click "datasets", "New Dataset", and choose "Athena".

# %% [markdown]
# ![quicksight_04.png](attachment:quicksight_04.png)

# %% [markdown]
# ![quicksight_05.png](attachment:quicksight_05.png)

# %% [markdown]
# ## 5) Click Edit/Preview data. Click "add data", select the table "ratings" and then hit "Select".

# %% [markdown]
# ## 6) Select the join between the tables, and change the columns to "movieid" on both sides.

# %% [markdown]
# ![quicksight_06.png](attachment:quicksight_06.png)

# %% [markdown]
# ## 7) Now click "Save & visualize" to start creating your first visualization

# %% [markdown]
# ## 8) Select the fields rating and title and change the value to: rating(Average):

# %% [markdown]
# ![quicksight_07.png](attachment:quicksight_07.png)

# %% [markdown]
# ## 9) Click filter, create one, movieid[ratings], change the aggregation to "count", greather then 1000:

# %% [markdown]
# ![quicksight_08.png](attachment:quicksight_08.png)

# %% [markdown]
# ## 10) That's right! Now we have the 5 best films, according to the queries of the previous labs!

# %% [markdown]
# ![quicksight_09.png](attachment:quicksight_09.png)
