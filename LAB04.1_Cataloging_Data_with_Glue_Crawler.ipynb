# %% [markdown]
# ## Optionally, we can use the Glue Crawler to create the tables:

# %% [markdown]
# ![LAB04.1_Cataloging_Data_with_Glue_Crawler.png](attachment:LAB04.1_Cataloging_Data_with_Glue_Crawler.png)

# %% [markdown]
# ## 1) Go to AWS Glue, click Databases, "Add database", type "movielens" and hit "Create":

# %% [markdown]
# ![glue_00.png](attachment:glue_00.png)

# %% [markdown]
# ## 2) Go to AWS Glue, and click on the "Crawlers" option.

# %% [markdown]
# ## 3) Click "Add crawler", and follow the options bellow:

# %% [markdown]
# ![glue_01.png](attachment:glue_01.png)

# %% [markdown]
# ![glue_02.png](attachment:glue_02.png)

# %% [markdown]
# ![glue_03.png](attachment:glue_03.png)

# %% [markdown]
# ![glue_04.png](attachment:glue_04.png)

# %% [markdown]
# ![glue_05.png](attachment:glue_05.png)

# %% [markdown]
# ![glue_06.png](attachment:glue_06.png)

# %% [markdown]
# ![glue_07.png](attachment:glue_07.png)

# %% [markdown]
# ## 4) Now, run the crawler

# %% [markdown]
# ![glue_08.png](attachment:glue_08.png)

# %% [markdown]
# ## 5) This is it. Crawler found 3 tables and you can now start doing SQL queries on them.

# %% [markdown]
# ![glue_09.png](attachment:glue_09.png)
