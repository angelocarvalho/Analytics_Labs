# %% [markdown]
# ## You can use Cloud Formation to add security to your data lake, among other features

# %% [markdown]
# ![lake_formation_01.png](attachment:lake_formation_01.png)

# %% [markdown]
# ## 1) Run the Cloudformation "LakeFormationSetup.json"

# %% [markdown]
# ## 2) Follow the document "Configuring Lake Formation in a Single Account.pdf"
